# %% [markdown]
# ## Problem Set 20200904

# %% [markdown]
# ## problem statement-1(3n+1)
# "Consider the following algorithm to generate a sequence of numbers. Start with an
# integer n. If n is even, divide by 2. If n is odd, multiply by 3 and add 1. Repeat this
# process with the new value of n, terminating when n = 1. For example, the following
# sequence of numbers will be generated for n = 22:
#
# 22 11 34 17 52 26 13 40 20 10 5 16 8 4 2 1
#
# It is conjectured (but not yet proven) that this algorithm will terminate at n = 1 for
# every integer n. Still, the conjecture holds for all integers up to at least 1, 000, 000.
# For an input n, the cycle-length of n is the number of numbers generated up to and
# including the 1. In the example above, the cycle length of 22 is 16. Given any two
# numbers i and j, you are to determine the maximum cycle length over all numbers
# between i and j, including both endpoints.
# Input
# The input will consist of a series of pairs of integers i and j, one pair of integers per
# line. All integers will be less than 1,000,000 and greater than 0.
# Output
# For each pair of input integers i and j, output i, j in the same order in which they
# appeared in the input and then the maximum cycle length for integers between and
# including i and j. These three numbers should be separated by one space, with all three
# numbers on one line and with one line of output for each line of input.
#
# Sample Input
#
# 1 10
#
# 100 200
#
# 201 210
#
# 900 1000
#
# Sample Output
# 20
#
# 125
#
# 89
#
# 174"

# %%
def threen_plus_one_rule(lb,ub):
    mx=-1
    for i in range(lb,ub+1):
        cycle=1
        while(i!=1):
            if(i%2==0):
                i=i//2
                cycle+=1
            else:
                i=3*i+1
                cycle+=1
        if(mx<cycle):
            mx=cycle
    return mx
                
threen_plus_one_rule(600,800)
# Out:
# 171

# %% [markdown]
# ## problem statement-2-(minesweeper)
# Have you ever played Minesweeper? This cute little game comes with a certain op-
# erating system whose name we can’t remember. The goal of the game is to find where
#
# all the mines are located within a M × N field.
# The game shows a number in a square which tells you how many mines there are
# adjacent to that square. Each square has at most eight adjacent squares. The 4×4 field
# on the left contains two mines, each represented by a “*” character. If we represent the
# same field by the hint numbers described above, we end up with the field on the right:
#
# *...
# ....
# .*..
# ....
#
# *100
# 2210
# 1*10
# 1110
#
# Input
# The input will consist of an arbitrary number of fields. The first line of each field
# contains two integers n and m (0 < n, m ≤ 100) which stand for the number of lines
# and columns of the field, respectively. Each of the next n lines contains exactly m
# characters, representing the field.
# Safe squares are denoted by “.” and mine squares by “*,” both without the quotes.
# The first field line where n = m = 0 represents the end of input and should not be
# processed.
# Output
# For each field, print the message Field #x: on a line alone, where x stands for the
# number of the field starting from 1. The next n lines should contain the field with the
# “.” characters replaced by the number of mines adjacent to that square. There must
# be an empty line between field outputs.
#
# Sample Input
#
# 4 4
#
# *...
#
# ....
#
# .*..
#
# ....
#
# 3 5
#
# **...
#
# .....
#
# .*...
#
# 0 0
#
# Sample Output
#
# Field #1:
#
# *100
#
# 2210
#
# 1*10
#
# 1110
#
# Field #2:
#
# **100
#
# 33200
#
# 1*100

# %%
#Mineseeper method-1
def minesweeper(m,n,nums):
    for i in range(m):
        for j in range(n):
            count=0
            if nums[i][j]=='.' :
                if i==0:
                    if j==0:
                        if nums[0][1]=='*':
                            count+=1
                        if nums[1][0]=='*':
                            count+=1
                        if nums[1][1]=='*':
                            count+=1
                        print(count,end='')
                    elif j==n-1:
                        if nums[i][j-1]=='*':
                            count+=1
                        if nums[i+1][j-1]=='*':
                            count+=1
                        if nums[i+1][j]=='*':
                            count+=1
                        print(count,end='')
                    else:
                        if nums[i][j-1]=='*':
                            count+=1
                        if nums[i][j+1]=='*':
                            count+=1
                        if nums[i+1][j]=='*':
                            count+=1
                        if nums[i+1][j-1]=='*':
                            count+=1
                        if nums[i+1][j+1]=='*':
                            count+=1
                        print(count,end='')
                elif j==0 and i!=m-1:
                    count=0
                    if nums[i][j+1]=='*':
                        count+=1
                    if nums[i-1][j]=='*':
                        count+=1
                    if nums[i+1][j]=='*':
                        count+=1
                    if nums[i+1][j+1]=='*':
                        count+=1
                    if nums[i-1][j+1]=='*':
                        count+=1
                    print(count,end='')
                elif i==m-1:
                    count=0
                    if j==0:
                        if nums[i-1][j]=='*':
                            count+=1
                        if nums[i-1][j+1]=='*':
                            count+=1
                        if nums[i][j+1]=='*':
                            count+=1
                        print(count,end='')
                    elif j==n-1:
                        if nums[i][j-1]=='*':
                            count+=1
                        if nums[i-1][j-1]=='*':
                            count+=1
                        if nums[i-1][j]=='*':
                            count+=1
                        print(count,end='')
                    else:
                        if nums[i][j-1]=='*':
                            count+=1
                        if nums[i][j+1]=='*':
                            count+=1
                        if nums[i-1][j]=='*':
                            count+=1
                        if nums[i-1][j-1]=='*':
                            count+=1
                        if nums[i-1][j+1]=='*':
                            count+=1
                        print(count,end='')
                elif j==n-1:
                    if nums[i-1][j-1]=='*':
                        count+=1
                    if nums[i-1][j]=='*':
                        count+=1
                    if nums[i][j-1]=='*':
                        count+=1
                    if nums[i+1][j-1]=='*':
                        count+=1
                    if nums[i+1][j]=='*':
                        count+=1
                    print(count,end='')
                else:
                    count=0
                    if nums[i][j-1]=='*':
                        count+=1
                    if nums[i][j+1]=='*':
                        count+=1
                    if nums[i+1][j-1]=='*':
                        count+=1
                    if nums [i+1][j]=='*':
                        count+=1
                    if nums[i+1][j+1]=='*':
                        count+=1
                    if nums[i-1][j-1]=='*':
                        count+=1
                    if nums[i-1][j]=='*':
                        count+=1
                    if nums[i-1][j+1]=='*':
                        count+=1
                    print(count,end='')
            else:
                print('*',end='')
        print("",end="\n")
    
minesweeper(3,5,[['*','*','.','.','.'],['.','.','.','.','.'],['.','*','.','.','.']])
print()
minesweeper(4,4,[['*','.','.','.'],['.','.','.','.'],['.','*','.','.'],['.','.','.','.']])
# Out:
# **100
# 33200
# 1*100
#
# *100
# 2210
# 1*10
# 1110

# %%
#minesweeper - method 2
def minesweeper():
    m=int(input('enter no of rows'))
    n=int(input('enter no of columns'))
    nums=getInput(m)
    for i in range(m):
        for j in range(n):
            count=0
            if nums[i][j]=='.' :
                if j-1!=-1 and nums[i][j-1]=='*':
                    count+=1
                if j+1!=n and nums[i][j+1]=='*':
                    count+=1
                if i+1!=m and j-1!=-1 and nums[i+1][j-1]=='*':
                    count+=1
                if  i+1!=m and nums[i+1][j]=='*':
                    count+=1
                if i+1!=m and j+1!=n and nums[i+1][j+1]=='*':
                    count+=1
                if  i-1!=-1 and j-1!=-1 and nums[i-1][j-1]=='*':
                    count+=1
                if  i-1!=-1 and nums[i-1][j]=='*':
                    count+=1
                if i-1!=-1 and j+1!=n and nums[i-1][j+1]=='*':
                    count+=1
                print(count,end='')
            else:
                print('*',end='')
        print("",end="\n")
        
def getInput(r):
    data = []
    print('enter the input')
    for i in range(r):
        line = input().split(' ')
        data.append(line)
    return data
    
minesweeper()
# Out:
# enter no of rows4
# enter no of columns4
# enter the input
# * . . .
# . . . .
# . * . .
# . . . .
# *100
# 2210
# 1*10
# 1110

# %% [markdown]
# ## PROBLEM STATEMENT-3

# %% [markdown]
#  The TripPC/UVa IDs: 110103/10137, Popularity: B, Success rate: average Level: 1A
#
#  group of students are members of a club that travels annually to different lo- cations. Their destinations in the past have included Indianapolis, Phoenix, Nashville,Philadelphia, San Jose, and Atlanta. This spring they are planning a trip to Eindhoven.The group agrees in advance to share expenses equally, but it is not practical to shareevery expense as it occurs. Thus individuals in the group pay for particular things, suchas meals, hotels, taxi rides, and plane tickets. After the trip, each student’s expensesare tallied and money is exchanged so that the net cost to each is the same, to withinone cent.
#
#  In the past, this money exchange has been tedious and time consuming. Yourjob is to compute, from a list of expenses, the minimum amount of money that mustchange hands in order to equalize (within one cent) all the students’ costs.InputStandard input will contain the information for several trips. Each trip consists of aline containing a positive integer n denoting the number of students on the trip. This isfollowed by n lines of input, each containing the amount spent by a student in dollarsand cents.
#
#  There are no more than 1000 students and no student spent more than$10,000.00. A single line containing 0 follows the information for the last trip.OutputFor each trip, output a line stating the total amount of money, in dollars and cents,that must be exchanged to equalize the students’ costs.
#
#  Sample Input
#
#  3
#
#  10.00
#
#  20.00
#
#  30.00
#
#  4
#
#  15.00
#
#  15.01
#
#  3.00
#
#  3.010
#
#  Sample Output
#
#  $10.00
#
#  $11.99

# %%
def exchange_money(m):
    nav=[]
    summ=0
    for i in range(m):
        nav.append(float(input()))
    print(nav)
    avg=sum(nav)/len(nav)
    for i in nav:
        if i>=avg:
            summ+=(i-avg)
    return "$"+str(summ)
exchange_money(4)
# Out:
# 10.00
# 5.00
# 7.5
# 10.00
# [10.0, 5.0, 7.5, 10.0]
# 8.125
# '$3.75'

# %% [markdown]
# ## PROBLEM-4(LCD)

# %%
res=[]
def one(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            k+=1
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            k+=1
        res[k].append(" ")
    else:  
        res.append([" "])
        for i in range(size):
            res.append(["|"])
        res.append([" "])
        for i in range(size):
            res.append(["|"])
        res.append([" "])
    return res

def two(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            for i in range(size+1):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size+1):
                res[k].append(" ")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size+1):
                res[k].append(" ")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def three(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            for i in range(size+1):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            for i in range(size+1):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def four(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append(" ")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")    
    return res


def five(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append(" ")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append(" ")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size+1):
                res[k].append(" ")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def six(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append(" ")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size+1):
                res[k].append(" ")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def seven(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            for i in range(size+1):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            for i in range(size+1):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")    
    return res


def eight(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def nine(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append(" ")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append([" "])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res


def zero(nav,n,size):
    if n!=0:
        k=0
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res[k].append("|")
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res[k].append(" ")
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
    else:
        k=0
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append(" ")
        res[k].append(" ")
        k+=1
        for i in range(size):
            res.append(["|"])
            for i in range(size):
                res[k].append(" ")
            res[k].append("|")
            k+=1
        res.append([" "])
        for i in range(size):
            res[k].append("-")
        res[k].append(" ")    
    return res

def lcd_display(size,number):
    nav=[]
    for i in range(len(number)):
        nav.append(int(number[i]))
    print(nav)
    for i in range(len(nav)):
        if nav[i]==1:
            one(nav,i,size)
        elif nav[i]==2:
            two(nav,i,size)
        elif nav[i]==3:
            three(nav,i,size)
        elif nav[i]==4:
            four(nav,i,size)
        elif nav[i]==5:
            five(nav,i,size)
        elif nav[i]==6:
            six(nav,i,size)
        elif nav[i]==7:
            seven(nav,i,size)
        elif nav[i]==8:
            eight(nav,i,size)
        elif nav[i]==9:
            nine(nav,i,size)
        else:
            zero(nav,i,size)
    for i in range(len(res)):
        for j in range(len(res[0])):
            print(res[i][j], end="")
        print()
    return "SUCCESS"
lcd_display(2,'0984321567890')
# Out:
# [0, 9, 8, 4, 3, 2, 1, 5, 6, 7, 8, 9, 0]
#  --  --  --      --  --   --  --  --  --  --  --
# |  ||  ||  ||  |   |   |||   |      ||  ||  ||  |
# |  ||  ||  ||  |   |   |||   |      ||  ||  ||  |
#      --  --  --  --  --   --  --      --  --
# |  |   ||  |   |   ||   |   ||  |   ||  |   ||  |
# |  |   ||  |   |   ||   |   ||  |   ||  |   ||  |
#  --  --  --      --  --   --  --      --  --  --
# 'SUCCESS'

# %% [markdown]
# # PROBLEM-5

# %% [markdown]
# ## 1.6.7 Check the Check
#
# PC/UVa IDs: 110107/10196, Popularity: B, Success rate: average Level: 1
#
# Your task is to write a program that reads a chessboard configuration and identifies
# whether a king is under attack (in check). A king is in check if it is on square which
# can be taken by the opponent on his next move.
#
# White pieces will be represented by uppercase letters, and black pieces by lowercase
# letters. The white side will always be on the bottom of the board, with the black side
# always on the top.
#
# For those unfamiliar with chess, here are the movements of each piece:
#
# Pawn (p or P): can only move straight ahead, one square at a time. However, it takes
# pieces diagonally, and that is what concerns you in this problem.
#
# Knight (n or N) : has an L-shaped movement shown below. It is the only piece that
# can jump over other pieces.
#
# Bishop (b or B) : can move any number of squares diagonally, either forward or
# backward.
#
# Rook (r or R) : can move any number of squares vertically or horizontally, either
# forward or backward.
#
# Queen (q or Q) : can move any number of squares in any direction (diagonally,
# horizontally, or vertically) either forward or backward.
#
# King (k or K) : can move one square at a time in any direction (diagonally,
# horizontally, or vertically) either forward or backward.
#
# Movement examples are shown below, where “*” indicates the positions where the
# piece can capture another piece:
#
# Pawn Rook Bishop Queen King Knight
#
# ........ ...*.... .......* ...*...* ........ ........
#
# ........ ...*.... *.....*. *..*..*. ........ ........
#
# ........ ...*.... .*...*.. .*.*.*.. ........ ..*.*...
#
# ........ ...*.... ..*.*... ..***... ..***... .*...*..
#
# ...p.... ***r**** ...b.... ***q**** ..*k*... ...n....
#
# ..*.*... ...*.... ..*.*... ..***... ..***... .*...*..
#
# ........ ...*.... .*...*.. .*.*.*.. ........ ..*.*...
#
# ........ ...*.... *.....*. *..*..*. ........ ........
#
# Remember that the knight is the only piece that can jump over other pieces. The
# pawn movement will depend on its side. If it is a black pawn, it can only move one
# square diagonally down the board. If it is a white pawn, it can only move one square
# diagonally up the board. The example above is a black pawn, described by a lowercase
# “p”. We use “move” to indicate the squares where the pawn can capture another piece.
#
# 24 1. Getting Started
#
# ### Input
#
# There will be an arbitrary number of board configurations in the input, each consisting
#
# of eight lines of eight characters each. A “.” denotes an empty square, while upper-
# and lowercase letters represent the pieces as defined above. There will be no invalid
#
# characters and no configurations where both kings are in check. You must read until you
# find an empty board consisting only of “.” characters, which should not be processed.
# There will be an empty line between each pair of board configurations. All boards,
# except for the empty one, will contain exactly one white king and one black king.
#
# ### Output
#
# For each board configuration read you must output one of the following answers:
#
# Game #d: white king is in check.
#
# Game #d: black king is in check.
#
# Game #d: no king is in check.
#
# where d stands for the game number starting from 1.
#
# ### Sample Input
#
# ..k.....
#
# ppp.pppp
#
# ........
#
# .R...B..
#
# ........
#
# ........
#
# PPPPPPPP
#
# K.......
#
# rnbqk.nr
#
# ppp..ppp
#
# ....p...
#
# ...p....
#
# .bPP....
#
# .....N..
#
# PP..PPPP
#
# RNBQKB.R
#
# ........
#
# ........
#
# ........
#
# ........
#
# ........
#
# ........
#
# ........
#
# ........
#
# ### Sample Output
#
# Game #1: black king is in check.
#
# Game #2: white king is in check.

# %%
res=[]
PAWN=[]
KNIGHT=[]
QUEEN=[]
ROOK=[]
BISHOP=[]
pawn=[]
knight=[]
queen=[]
rook=[]
bishop=[]
def get_indexes():
    for i in range(8):
        for j in range(8):
            if res[i][j]!='.':
                if res[i][j]=='P':
                    PAWN.append([i,j])
                elif res[i][j]=='p':
                    pawn.append([i,j])
                elif res[i][j]=='B':
                    BISHOP.append([i,j])
                elif res[i][j]=='Q':
                    QUEEN.append([i,j])
                elif res[i][j]=='R':
                    ROOK.append([i,j])
                elif res[i][j]=='N':
                    KNIGHT.append([i,j])
                elif res[i][j]=='n':
                    knight.append([i,j])
                elif res[i][j]=='b':
                    bishop.append([i,j])
                elif res[i][j]=='q':
                    queen.append([i,j])
                elif res[i][j]=='r':
                    rook.append([i,j])
    return "indexes are generated"
        
def check_the_check():
    print("enter the 8 rows")
    for i in range(8):
        res.append(list(input()))
    get_indexes()
    for i in range(len(PAWN)):
        if  (PAWN[i][0]-1)!=-1 and (PAWN[i][1]+1)<=7 and res[PAWN[i][0]-1][PAWN[i][1]+1]=='k':
            return "Black king is in check"
        elif  PAWN[i][0]-1!=-1 and PAWN[i][1]-1!=-1 and res[PAWN[i][0]-1][PAWN[i][1]-1]=='k':
            return  "Black king is in check"
    for i in range(len(pawn)):
        if  (pawn[i][0]+1)<=7 and (pawn[i][1]-1)!=-1 and res[pawn[i][0]+1][pawn[i][1]-1]=='K':
            return "white king is in check"
        elif  pawn[i][0]+1<=7 and pawn[i][1]+1<=7 and res[pawn[i][0]+1][pawn[i][1]+1]=='K':
            return  "white king is in check"
    #checking with rook
    if ROOK!=[]:
        for j in range(len(ROOK)):
            for i in reversed(range(ROOK[j][0])):
                if res[i][ROOK[j][1]]=='k':
                    return "black king is in check"
                if res[i][ROOK[j][1]]!='.':
                     break
            for i in range(ROOK[j][0]+1,8):
                if res[i][ROOK[j][1]]=='k':
                    return "black king is in check"
                if res[i][ROOK[j][1]]!='.':
                    break
            for i in reversed(range(ROOK[j][1])):
                if res[ROOK[j][0]][i]=='k':
                    return "black king is in check"
                if res[ROOK[0][0]][i]!='.':
                    break
            for i in range(ROOK[j][1]+1,8):
                if res[ROOK[j][0]][i]=='k':
                    return "black king is in check"
                if res[ROOK[j][0]][i]!='.':
                    break
    if rook!=[]:
        for j in range(len(rook)):
            for i in reversed(range(rook[j][0])):
                if res[i][rook[j][1]]=='K':
                    return "white king is in check"
                if res[i][rook[j][1]]!='.':
                    break
            for i in range(rook[j][0]+1,8):
                if res[i][rook[j][1]]=='K':
                    return "white king is in check"
                if res[i][rook[j][1]]!='.':
                    break
            for i in reversed(range(rook[j][1])):
                if res[rook[j][0]][i]=='K':
                    return "white king is in check"
                if res[rook[j][0]][i]!='.':
                    break
            for i in range(rook[j][1]+1,8):
                if res[rook[j][0]][i]=='K':
                    return "white king is in check"
                if res[rook[j][0]][i]!='.':
                    break
    #checking for bishop
    
    if BISHOP!=[]:
        for i in range(len(BISHOP)):
            m=BISHOP[i][0]
            n=BISHOP[i][1]
            a=m
            b=n
            while(a!=0 and b!=0):
                if res[a-1][b-1]=='k':
                    return 'black king is in check'
                if res[a-1][b-1]!='.':
                    break
                a=a-1
                b=b-1
            a=m
            b=n
            while(a!=0 and b<7):
                if res[a-1][b+1]=='k':
                    return 'black king is in check'
                if res[a-1][b+1]!='.':
                    break
                a=a-1
                b=b+1
            a=m
            b=n
            while(a<7 and b!=0):
                if res[a+1][b-1]=='k':
                    return 'black king is in check'
                if res[a+1][b-1]!='.':
                    break
                a=a+1
                b=b-1
            a=m
            b=n
            while(a<7 and b<7):
                if res[a+1][b+1]=='k':
                    return 'black king is in check'
                if res[a+1][b+1]!='.':
                    break
                a+=1
                b+=1
        
    if bishop!=[]:
        for j in range(len(bishop)):
            m=bishop[j][0]
            n=bishop[j][1]
            a=m
            b=n
            while(a!=0 and b!=0):
                if res[a-1][b-1]=='K':
                    return 'white king is in check'
                if res[a-1][b-1]!='.':
                    break
                a=a-1
                b=b-1
            a=m
            b=n
            while(a!=0 and b<7):
                if res[a-1][b+1]=='K':
                    return 'white king is in check'
                if res[a-1][b+1]!='.':
                    break
                a=a-1
                b=b+1
            a=m
            b=n
            while(a<7 and b!=0):
                if res[a+1][b-1]=='K':
                    return 'white king is in check'
                if res[a+1][b-1]!='.':
                    break
                a=a+1
                b=b-1
            a=m
            b=n
            while(a<7 and b<7):
                if res[a+1][b+1]=='K':
                    return 'white king is in check'
                if res[a+1][b+1]!='.':
                    break
                a+=1
                b+=1    
     # check with queen
    if QUEEN!=[]:
        for i in reversed(range(QUEEN[0][0])):
            if res[i][QUEEN[0][1]]=='k':
                return "black king is in check"
            if res[i][QUEEN[0][1]]!='.':
                break
        for i in range(QUEEN[0][0]+1,8):
            if res[i][QUEEN[0][1]]=='k':
                return "black king is in check"
            if res[i][QUEEN[0][1]]!='.':
                break
        for i in reversed(range(QUEEN[0][1])):
            if res[QUEEN[0][0]][i]=='k':
                return "black king is in check"
            if res[QUEEN[0][0]][i]!='.':
                break
        for i in range(QUEEN[0][1]+1,8):
            if res[QUEEN[0][0]][i]=='k':
                return "black king is in check"
            if res[QUEEN[0][0]][i]!='.':
                break
        m=QUEEN[0][0]
        n=QUEEN[0][1]
        a=m
        b=n
        while(a!=0 and b!=0):
            if res[a-1][b-1]=='k':
                return 'black king is in check'
            if res[a-1][b-1]!='.':
                break
            a=a-1
            b=b-1
        a=m
        b=n
        while(a!=0 and b<7):
            if res[a-1][b+1]=='k':
                return 'black king is in check'
            if res[a-1][b+1]!='.':
                break
            a=a-1
            b=b+1
        a=m
        b=n
        while(a<7 and b!=0):
            if res[a+1][b-1]=='k':
                return 'black king is in check'
            if res[a+1][b-1]!='.':
                break
            a=a+1
            b=b-1
        a=m
        b=n
        while(a<7 and b<7):
            if res[a+1][b+1]=='k':
                return 'black king is in check'
            if res[a+1][b+1]!='.':
                break
            a+=1
            b+=1
    if queen!=[]:
        for i in reversed(range(queen[0][0])):
            if res[i][queen[0][1]]=='K':
                return "white king is in check"
            if res[i][queen[0][1]]!='.':
                break
        for i in range(queen[0][0]+1,8):
            if res[i][queen[0][1]]=='K':
                return "white king is in check"
            if res[i][queen[0][1]]!='.':
                break
        for i in reversed(range(queen[0][1])):
            if res[queen[0][0]][i]=='K':
                return "white king is in check"
            if res[queen[0][0]][i]!='.':
                break
        for i in range(queen[0][1]+1,8):
            if res[queen[0][0]][i]=='K':
                return "white king is in check"
            if res[[0][0]][i]!='.':
                break
        m=queen[0][0]
        n=queen[0][1]
        a=m
        b=n
        while(a!=0 and b!=0):
            if res[a-1][b-1]=='K':
                return 'white king is in check'
            if res[a-1][b-1]!='.':
                break
            a=a-1
            b=b-1
        a=m
        b=n
        while(a!=0 and b<7):
            if res[a-1][b+1]=='K':
                return 'white king is in check'
            if res[a-1][b+1]!='.':
                break
            a=a-1
            b=b+1
        a=m
        b=n
        while(a<7 and b!=0):
            if res[a+1][b-1]=='K':
                return 'white king is in check'
            if res[a+1][b-1]!='.':
                break
            a=a+1
            b=b-1
        a=m
        b=n
        while(a<7 and b<7):
            if res[a+1][b+1]=='K':
                return 'white king is in check'
            if res[a+1][b+1]!='.':
                break
            a+=1
            b+=1
    #checking with knight
    if KNIGHT!=[]:
        for j in range(len(KNIGHT)):
            m=KNIGHT[j][0]
            n=KNIGHT[j][1]
            if m-1>=0 and n-2>=0 and res[m-1][n-2]=='k':
                return "black king is in check"
            if m-2 >=0 and n-1 >=0 and res[m-2][n-1]=='k':
                return 'black king is in check'
            if  m+1<=7 and n-2 >=0 and res[m+1][n-2]=='k':
                return 'black king is in check'
            if m+2 <=7 and n-1 >=0 and res[m+2][n-1]=='k':
                return 'black king is in check'
            if  m-2 >=0 and n+1<=7 and res[m-2][n+1]=='k':
                return 'black king is in check'
            if m-1>=0 and n+2<=7 and  res[m-1][n+2]=='k':
                return 'black king is in check'
            if  m+2<=7 and n+1<=7 and res[m+2][n+1]=='k':
                return 'black king is in check'
            if  m+1<=7 and n+2<=7 and res[m+1][n+2]=='k':
                return 'black king is in check'
            
    if knight!=[]:
        for j in range(len(knight)):
            m=knight[j][0]
            n=knight[j][1]
            if m-1>=0 and n-2>=0 and res[m-1][n-2]=='K':
                return "white king is in check"
            if m-2 >=0 and n-1 >=0 and res[m-2][n-1]=='K':
                return 'white king is in check'
            if  m+1<=7 and n-2 >=0 and res[m+1][n-2]=='K':
                return 'white king is in check'
            if m+2 <=7 and n-1 >=0 and res[m+2][n-1]=='K':
                return 'white king is in check'
            if  m-2 >=0 and n+1<=7 and res[m-2][n+1]=='K':
                return 'white king is in check'
            if m-1>=0 and n+2<=7 and  res[m-1][n+2]=='K':
                return 'white king is in check'
            if  m+2<=7 and n+1<=7 and res[m+2][n+1]=='K':
                return 'white king is in check'
            if  m+1<=7 and n+2<=7 and res[m+1][n+2]=='K':
                return 'white king is in check'        
    return "no king is in danger"
check_the_check()
# Out:
# enter the 8 rows
# ..k.....
# ppp.pppp
# ........
# .R...B..
# ........
# ........
# PPPPPPPP
# K.......
# 'black king is in check'

# %% [markdown]
# ## PROBLEM-6

# %% [markdown]
# 1.6.8 Australian Voting
#
# PC/UVa IDs: 110108/10142, Popularity: B, Success rate: low Level: 1
#
# Australian ballots require that voters rank all the candidates in order of choice.
# Initially only the first choices are counted, and if one candidate receives more than 50%
# of the vote then that candidate is elected. However, if no candidate receives more than
# 50%, all candidates tied for the lowest number of votes are eliminated.
#
# Ballots ranking
# these candidates first are recounted in favor of their highest-ranked non-eliminated
# candidate. This process of eliminating the weakest candidates and counting their ballots
# in favor of the preferred non-eliminated candidate continues until one candidate receives
# more than 50% of the vote, or until all remaining candidates are tied.
#
# ### Input
#
# The input begins with a single positive integer on a line by itself indicating the number
# of cases following, each as described below. This line is followed by a blank line. There
# is also a blank line between two consecutive inputs.
#
# The first line of each case is an integer n ≤ 20 indicating the number of candidates.
#
# The next n lines consist of the names of the candidates in order, each up to 80 char-
# acters in length and containing any printable characters. Up to 1,000 lines follow, each
# containing the contents of a ballot. Each ballot contains the numbers from 1 to n in
# some order. The first number indicates the candidate of first choice; the second number
# indicates candidate of second choice, and so on.
#
# ### Output
#
# The output of each test case consists of either a single line containing the name of the
# winner or several lines containing the names of all candidates who are tied. The output
# of each two consecutive cases are separated by a blank line.
#
# ### Sample Input
#
# 1
#
# 3
#
# John Doe
#
# Jane Smith
#
# Jane Austen
#
# 123
#
# 213
#
# 231
#
# 123
#
# 312
#
# ### output
#
# John Doe

# %%
def Australian_voting():
    candidate_list=[]
    voters_list=[]
    result=[]
    tmp=[]
    candidates=int(input('enter the no of candidates'))
    for j in range(candidates):
        candidate_list.append(input('enter the candidate name'))
        result.append(0)
    result.append(0)
    n=int(input('enter the no of voters'))
    for i in range(n):
        lst=list(input().split(' '))
        voters_list.append(lst)
    print(voters_list)
    while(True):
        for i in range(candidates+1):
            result[i]=0
        for i in range(1):
            for j in range(n):
                result[int(voters_list[j][i])]+=1
        print(result)
        tmp=[]
        for k in range(1,candidates+1):
            if result[k]>=n/2:
                tmp.append(candidate_list[k-1])
        if tmp!=[]:
            return tmp
        mn=99
        for j in range(1,candidates+1):
            if mn>=result[j] and result[j]!=0:
                mn=result[j]
                temp=j
        print(temp)
        for i in range(n):
            voters_list[i].remove(str(temp))
        print(voters_list)
            
    print(result)
    return tmp
Australian_voting()
# Out:
# enter the no of candidates3
# enter the candidate nameJohn Doe
# enter the candidate namejane smith
# enter the candidate namejane austin
# enter the no of voters5
# 1 2 3
# 2 1 3
# 2 3 1
# 1 2 3
# 3 1 2
# [['1', '2', '3'], ['2', '1', '3'], ['2', '3', '1'], ['1', '2', '3'], ['3', '1', '2']]
# [0, 2, 2, 1]
# 3
# [['1', '2'], ['2', '1'], ['2', '1'], ['1', '2'], ['1', '2']]
# [0, 3, 2, 0]
# ['John Doe']
